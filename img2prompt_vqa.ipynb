# %% [markdown]
# ## Img2Prompt-VQA: Inference Demo

# %%
# install requirements
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !git clone https://github.com/salesforce/LAVIS
    # %cd LAVIS
    # !pip install .
    # !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz
else:
    # !pip install omegaconf
    # %cd ../..
    # !pip install .
    # !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz

# %cd projects/img2prompt-vqa
# Out:
# Running in Colab.
# Cloning into 'LAVIS'...
# remote: Enumerating objects: 5848, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 5848 (delta 50), reused 78 (delta 47), pack-reused 5759
# Receiving objects: 100% (5848/5848), 46.65 MiB | 29.38 MiB/s, done.
# Resolving deltas: 100% (3963/3963), done.
# /content/LAVIS
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/LAVIS
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting contexttimer
#   Downloading contexttimer-0.3.3.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 67.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (4.65.0)
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (5.13.1)
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (0.14.1+cu116)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (7.9.0)
# Collecting pre-commit
#   Downloading pre_commit-3.2.0-py2.py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 KB 26.3 MB/s eta 0:00:00
# Collecting einops>=0.4.1
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (0.40.0)
# Collecting streamlit
#   Downloading streamlit-1.20.0-py2.py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 83.8 MB/s eta 0:00:00
# Collecting webdataset
#   Downloading webdataset-0.2.48-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (0.19.3)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (1.4.4)
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (2.0.6)
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Collecting fairscale==0.4.4
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 KB 28.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers<4.27,>=4.25.0
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 71.9 MB/s eta 0:00:00
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 16.1 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (3.5.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from salesforce-lavis==1.0.1) (23.0)
# Collecting opencv-python-headless==4.5.5.64
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.9/dist-packages (from opencv-python-headless==4.5.5.64->salesforce-lavis==1.0.1) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->salesforce-lavis==1.0.1) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 102.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (3.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (2.27.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->salesforce-lavis==1.0.1) (0.2.6)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (63.4.3)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->salesforce-lavis==1.0.1) (4.4.2)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets->salesforce-lavis==1.0.1) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets->salesforce-lavis==1.0.1) (8.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->salesforce-lavis==1.0.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->salesforce-lavis==1.0.1) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->salesforce-lavis==1.0.1) (8.2.2)
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting identify>=1.0.0
#   Downloading identify-2.5.21-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 KB 13.8 MB/s eta 0:00:00
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.7.0-py2.py3-none-any.whl (21 kB)
# Collecting virtualenv>=20.10.0
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 47.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from pycocotools->salesforce-lavis==1.0.1) (3.7.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (2023.3.15)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (3.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (1.10.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (2.25.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->salesforce-lavis==1.0.1) (1.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (1.1.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (1.10.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (2.4.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (2.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (3.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (6.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (8.1.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy->salesforce-lavis==1.0.1) (2.0.8)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (5.3.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (9.0.0)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (6.0.0)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.1 MB/s eta 0:00:00
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (3.19.6)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (4.2)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (4.2.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (0.10.2)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit->salesforce-lavis==1.0.1) (6.2)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.2-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 30.7 MB/s eta 0:00:00
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis==1.0.1) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis==1.0.1) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis==1.0.1) (4.3.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->salesforce-lavis==1.0.1) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->salesforce-lavis==1.0.1) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (5.12.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->salesforce-lavis==1.0.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy->salesforce-lavis==1.0.1) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers<4.27,>=4.25.0->salesforce-lavis==1.0.1) (1.26.15)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 12.8 MB/s eta 0:00:00
# Collecting pygments
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.6 MB/s eta 0:00:00
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->salesforce-lavis==1.0.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->salesforce-lavis==1.0.1) (0.0.4)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->salesforce-lavis==1.0.1) (0.1.0.post0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 27.0 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.10.0->pre-commit->salesforce-lavis==1.0.1) (3.1.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets->salesforce-lavis==1.0.1) (8.0.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython->salesforce-lavis==1.0.1) (0.7.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->salesforce-lavis==1.0.1) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->salesforce-lavis==1.0.1) (0.19.3)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets->salesforce-lavis==1.0.1) (1.3)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->salesforce-lavis==1.0.1) (2022.7)
# Building wheels for collected packages: salesforce-lavis, fairscale, contexttimer, iopath, antlr4-python3-runtime, validators
#   Building wheel for salesforce-lavis (pyproject.toml) ... done
#   Created wheel for salesforce-lavis: filename=salesforce_lavis-1.0.1-py3-none-any.whl size=1828097 sha256=db95739af092800c50f5182eefaf14445029fd5a9f2faa1446bd1a892297be3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lvhczlkh/wheels/a7/42/c1/b22118b13613bf4b2317990da7f7484b8e5303fcda72498923
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292853 sha256=fa30df692d3f05e9aae7032403e5c686a7c0ef5b80936eb957a275d64bcd0304
#   Stored in directory: /root/.cache/pip/wheels/71/88/74/ffb4fe1dd6799cbf410bab623fa7fc27fc3e1973a71a634a9d
#   Building wheel for contexttimer (setup.py) ... done
#   Created wheel for contexttimer: filename=contexttimer-0.3.3-py3-none-any.whl size=5816 sha256=cac27f679fdf90c9680d58eeba7118e585a1390f450b6bb92c96ea3465543b4a
#   Stored in directory: /root/.cache/pip/wheels/85/c5/df/e998b72ee60e27919121a304e2d2ac3f1c7bc2d31524afa355
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=aee38b1799239b2a1251991a3ff22f44873b21657285b4bb0cfaf3c91aca8520
#   Stored in directory: /root/.cache/pip/wheels/c1/13/6d/441d8f2af76ee6d2a3e67eebb1d0c556fefcee0a8b32266a8e
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=11256228b7d49720f10c7e7038e027df77d48da6ff8c2f2e5dea60d602e25641
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=5f4d1fc610f16bffe0c0e919b0c7bbe2b49ae78ecbc750ef2d3e61f158c194bf
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built salesforce-lavis fairscale contexttimer iopath antlr4-python3-runtime validators
# Installing collected packages: tokenizers, sentencepiece, distlib, contexttimer, braceexpand, antlr4-python3-runtime, webdataset, watchdog, virtualenv, validators, smmap, semver, python-magic, pympler, pygments, portalocker, opencv-python-headless, omegaconf, nodeenv, mdurl, jedi, identify, ftfy, einops, decord, cfgv, blinker, pydeck, pre-commit, markdown-it-py, iopath, huggingface-hub, gitdb, fairscale, transformers, timm, rich, opendatasets, gitpython, streamlit, pycocoevalcap, salesforce-lavis
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# Successfully installed antlr4-python3-runtime-4.9.3 blinker-1.5 braceexpand-0.1.7 cfgv-3.3.1 contexttimer-0.3.3 decord-0.6.0 distlib-0.3.6 einops-0.6.0 fairscale-0.4.4 ftfy-6.1.1 gitdb-4.0.10 gitpython-3.1.31 huggingface-hub-0.13.3 identify-2.5.21 iopath-0.1.10 jedi-0.18.2 markdown-it-py-2.2.0 mdurl-0.1.2 nodeenv-1.7.0 omegaconf-2.3.0 opencv-python-headless-4.5.5.64 opendatasets-0.1.22 portalocker-2.7.0 pre-commit-3.2.0 pycocoevalcap-1.2 pydeck-0.8.0 pygments-2.14.0 pympler-1.0.1 python-magic-0.4.27 rich-13.3.2 salesforce-lavis-1.0.1 semver-2.13.0 sentencepiece-0.1.97 smmap-5.0.0 streamlit-1.20.0 timm-0.4.12 tokenizers-0.13.2 transformers-4.26.1 validators-0.20.0 virtualenv-20.21.0 watchdog-3.0.0 webdataset-0.2.48
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 25.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting spacy<3.1.0,>=3.0.0
#   Downloading spacy-3.0.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.8)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.1)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 71.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (63.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.65.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.27.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.22.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.8)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (668 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.8/668.8 KB 56.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.15)
# Collecting click<7.2.0,>=7.1.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 KB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.1.2)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-3.0.0-py3-none-any.whl size=13704321 sha256=9d3e0cf5fbd6b98e43f0ff53b3e31cf477bd02c38cabf93870e224a28c6c80d4
#   Stored in directory: /root/.cache/pip/wheels/88/16/62/706709a80d48c983fffc44547114a933c464cd032e19378fb2
# Successfully built en-core-web-sm
# Installing collected packages: wasabi, pydantic, click, typer, thinc, spacy, en-core-web-sm
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.1
#     Uninstalling wasabi-1.1.1:
#       Successfully uninstalled wasabi-1.1.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.6
#     Uninstalling pydantic-1.10.6:
#       Successfully uninstalled pydantic-1.10.6
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.9
#     Uninstalling thinc-8.1.9:
#       Successfully uninstalled thinc-8.1.9
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.1
#     Uninstalling spacy-3.5.1:
#       Successfully uninstalled spacy-3.5.1
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.5.0
#     Uninstalling en-core-web-sm-3.5.0:
#       Successfully uninstalled en-core-web-sm-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 6.0.2 requires pydantic>=1.9.1, but you have pydantic 1.8.2 which is incompatible.
# flask 2.2.3 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# Successfully installed click-7.1.2 en-core-web-sm-3.0.0 pydantic-1.8.2 spacy-3.0.9 thinc-8.0.17 typer-0.3.2 wasabi-0.10.1
# /content/LAVIS/projects/img2prompt-vqa

# %%
import torch
import requests
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np

from lavis.common.gradcam import getAttMap
from lavis.models import load_model_and_preprocess

# %% [markdown]
# ### Load LLM to use

# %%
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM

def load_model(model_selection):
    model = AutoModelForCausalLM.from_pretrained(model_selection)
    tokenizer = AutoTokenizer.from_pretrained(model_selection, use_fast=False)
    return model,tokenizer

# Choose LLM to use
# weights for OPT-6.7B/OPT-13B/OPT-30B/OPT-66B will download automatically
print("Loading Large Language Model (LLM)...")
llm_model, tokenizer = load_model('facebook/opt-6.7b')  # ~13G (FP16)
# llm_model, tokenizer = load_model('facebook/opt-13b') # ~26G (FP16)
# llm_model, tokenizer = load_model('facebook/opt-30b') # ~60G (FP16)
# llm_model, tokenizer = load_model('facebook/opt-66b') # ~132G (FP16)

# you need to manually download weights, in order to use OPT-175B
# https://github.com/facebookresearch/metaseq/tree/main/projects/OPT
# llm_model, tokenizer = load_model('facebook/opt-175b')
# Out:
# Loading Large Language Model (LLM)...
# Downloading (…)lve/main/config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/41.9k [00:00<?, ?B/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/3.36G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]

# %%
# !ls
# Out:
# Caption.png  Illustration.png	   img2prompt_vqa.py	   README.md
# demo.png     img2prompt_vqa.ipynb  QuestionGeneration.png

# %% [markdown]
# ### Load an example image and question

# %%
# img_url = 'https://storage.googleapis.com/sfr-vision-language-research/LAVIS/projects/pnp-vqa/demo.png'
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')

# raw_image = Image.open("./demo.png").convert("RGB")
raw_image = Image.open("2.jpg").convert("RGB")
# question = "What item s are spinning which can be used to control electric?"
question = "What is the brown animal sitting inside of?"
print(question)
display(raw_image.resize((400, 300)))
# Out:
# What is the brown animal sitting inside of?
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FB29572BB20>

# %%
# setup device to use
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load Img2Prompt-VQA model

# %%
model, vis_processors, txt_processors = load_model_and_preprocess(name="img2prompt_vqa", model_type="base", is_eval=True, device=device)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
#   0%|          | 0.00/3.43G [00:00<?, ?B/s]
#   0%|          | 0.00/1.66G [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/656 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
#   0%|          | 0.00/2.92G [00:00<?, ?B/s]

# %% [markdown]
# ### Preprocess image and text inputs

# %%
image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)
question = txt_processors["eval"](question)

samples = {"image": image, "text_input": [question]}

# %% [markdown]
# ### Img2Prompt-VQA utilizes 4 submodels to perform VQA:
# #### 1. Image-Question Matching
# Compute the relevancy score of image patches with respect to the question using GradCAM

# %%
samples = model.forward_itm(samples=samples)

# %%
# Gradcam visualisation
dst_w = 720
w, h = raw_image.size
scaling_factor = dst_w / w

resized_img = raw_image.resize((int(w * scaling_factor), int(h * scaling_factor)))
norm_img = np.float32(resized_img) / 255
gradcam = samples['gradcams'].reshape(24,24)

avg_gradcam = getAttMap(norm_img, gradcam, blur=True)

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.imshow(avg_gradcam)
ax.set_yticks([])
ax.set_xticks([])
print('Question: {}'.format(question))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Question: what is the brown animal sitting inside of?

# %% [markdown]
# #### 2. Image Captioning
# Generate question-guided captions based on the relevancy score

# %%
samples = model.forward_cap(samples=samples, num_captions=50, num_patches=20)
print('Examples of question-guided captions: ')
samples['captions'][0][:5]
# Out:
# Examples of question-guided captions:
# ['a teddy bear and teddy bear bear in a box',
#  'this large brown teddy bear is in a small box',
#  'a large teddy bear sitting in a cardboard box attached to a key',
#  'a teddy bear sitting in a basket full of other objects',
#  'teddy bear teddy bear sitting in a stuffed teddy bear']

# %% [markdown]
# #### 3. Question Generation
# Generate synthetic questions using the captions

# %%
samples = model.forward_qa_generation(samples)
print('Sample Question: {} \nSample Answer: {}'.format(samples['questions'][:5], samples['answers'][:5]))
# Out:
# Sample Question: ['what is sitting in a box with a stuffed animal?', 'what is a brown teddy bear sitting in a box filled with?', 'what is a teddy bear sitting in?', 'how is a stuffed teddy bear in a box?', 'where is a teddy bear and teddy bear bear sitting?']
# Sample Answer: ['bear.', 'teddy.', 'box.', 'sitting.', 'a box.']

# %%
samples['questions']
# Out:
# ['what is sitting in a box with a stuffed animal?',
#  'what is a brown teddy bear sitting in a box filled with?',
#  'what is a teddy bear sitting in?',
#  'how is a stuffed teddy bear in a box?',
#  'where is a teddy bear and teddy bear bear sitting?',
#  'what is in a box with a pi?',
#  'what color is the teddy bear?',
#  'what kind of teddy bear is sitting in a box?',
#  'where is a teddy bear sitting in a box?',
#  'what is stuffed teddy bear sitting in a box filled with?',
#  'what type of box is a brown teddy bear sitting in?',
#  'how full is a brown teddy bear sitting in a box?',
#  'what size teddy bear is in a brown basket?',
#  'what kind of teddy bear is sitting in a toy box outside?',
#  'what does a teddy bear do inside of a box?',
#  'what size box is the brown teddy bear in?',
#  'where is a brown teddy bear sitting?',
#  'what is a brown teddy bear sitting in?',
#  'what is a teddy bear sitting in?',
#  "how full is a brown teddy bear's box?",
#  'what kind of box is the brown teddy bear sitting in?',
#  'where is the stuffed bear in his box sitting?',
#  'what is in a teddy bear sitting inside of a box?',
#  'a teddy bear is sitting in a basket full of what?',
#  'what is a teddy bear sitting in?',
#  'what is sitting in a box with a pi?',
#  'what type of box is the animal teddy bear sitting in?',
#  'what is in a box with a teddy bear?',
#  'what is sitting in a box with a stuffed animal?',
#  'what is brown teddy bear in a box full of?',
#  'is a teddy bear sitting in a box?']

# %% [markdown]
# #### 4. Prompt Construction
# Prepare the prompts for LLM

# %%
Img2Prompt = model.prompts_construction(samples)

# %% [markdown]
# #### 4. Load LLM and Predict Answers

# %%
# In this notebook, we only use CPU for LLM inference
# To run inference on GPU, see https://github.com/CR-Gjx/Img2Prompt for reference
device = "cpu"

def postprocess_Answer(text):
    for i, ans in enumerate(text):
        for j, w in enumerate(ans):
            if w == '.' or w == '\n':
                ans = ans[:j].lower()
                break
    return ans

Img2Prompt_input = tokenizer(Img2Prompt, padding='longest', truncation=True, return_tensors="pt").to(device)

assert (len(Img2Prompt_input.input_ids[0])+20) <=2048

outputs_list  = []
outputs = llm_model.generate(input_ids=Img2Prompt_input.input_ids,
                         attention_mask=Img2Prompt_input.attention_mask,
                         max_length=20+len(Img2Prompt_input.input_ids[0]),
                         return_dict_in_generate=True,
                         output_scores=True
                         )
outputs_list.append(outputs)

# %% [markdown]
# #### 5. Decoding to answers

# %%
outputs_list

pred_answer = tokenizer.batch_decode(outputs.sequences[:, len(Img2Prompt_input.input_ids[0]):])
pred_answer = postprocess_Answer(pred_answer)

print({"question": question, "answer": pred_answer})
# Out:
# {'question': 'what is the brown animal sitting inside of?', 'answer': 'a teddy bear'}
